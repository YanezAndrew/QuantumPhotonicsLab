# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
import numpy as np
from matplotlib.colors import LogNorm

# %%
df = pd.read_csv('data_2023-08-10 (50) - Lucidean.csv')
df
# Out:
#                          Time Temperature  \
# 0    Thu Aug 10 14:23:41 2023     293.742
# 1    Thu Aug 10 14:23:52 2023     293.741
# 2    Thu Aug 10 14:25:04 2023     293.742
# 3    Thu Aug 10 14:26:15 2023     293.742
# 4    Thu Aug 10 14:27:27 2023     293.743
# ..                        ...         ...
# 985  Fri Aug 11 10:13:04 2023       4.272
# 986  Fri Aug 11 10:14:18 2023       4.272
# 987  Fri Aug 11 10:15:31 2023       4.272
# 988  Fri Aug 11 10:16:45 2023       4.270
# 989  Fri Aug 11 10:17:58 2023       4.273
#
#                                                Voltage  \
# 0    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 1    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 2    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 3    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 4    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# ..                                                 ...
# 985  [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 986  [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 987  [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 988  [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 989  [2.0, 1.9193548387096775, 1.8387096774193548, ...
#
#                                                   Amps   Resistance
# 0    [0.0009999991, 0.0009999991, 0.001, 0.00099999...  5493.817640
# 1    [0.0009999992000000002, 0.0009999999, 0.001000...  5491.048434
# 2    [0.0009999995999999999, 0.0009999994999999999,...  5489.248750
# 3    [0.0009999989, 0.0009999997999999997, 0.000999...  5489.050748
# 4    [0.0009999985, 0.0010000005, 0.000999999299999...  5488.449370
# ..                                                 ...          ...
# 985  [0.0010000013000000002, 0.0009999998000000002,...  5657.800697
# 986  [0.0009999994999999999, 0.0009999998, 0.001, 0...  5658.013354
# 987  [0.0010000001999999999, 0.0009999995, 0.001, 0...  5657.706678
# 988  [0.0009999999000000002, 0.0010000000999999998,...  5657.242483
# 989  [0.0010000001, 0.0009999997, 0.0009999998, 0.0...  5657.767882
#
# [990 rows x 5 columns]

# %%
df['Voltage'] = df['Voltage'].apply(ast.literal_eval)
#df['Voltage'].values[0].apply(ast.literal_eval)

# %%
df['Voltage']
# Out:
# 0      [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 1      [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 2      [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 3      [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 4      [2.0, 1.9193548387096775, 1.8387096774193548, ...
#                              ...
# 985    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 986    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 987    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 988    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# 989    [2.0, 1.9193548387096775, 1.8387096774193548, ...
# Name: Voltage, Length: 990, dtype: object

# %%
df['Amps'] = df['Amps'].apply(ast.literal_eval)

# %%
df['Amps']
# Out:
# 0      [0.0009999991, 0.0009999991, 0.001, 0.00099999...
# 1      [0.0009999992000000002, 0.0009999999, 0.001000...
# 2      [0.0009999995999999999, 0.0009999994999999999,...
# 3      [0.0009999989, 0.0009999997999999997, 0.000999...
# 4      [0.0009999985, 0.0010000005, 0.000999999299999...
#                              ...
# 985    [0.0010000013000000002, 0.0009999998000000002,...
# 986    [0.0009999994999999999, 0.0009999998, 0.001, 0...
# 987    [0.0010000001999999999, 0.0009999995, 0.001, 0...
# 988    [0.0009999999000000002, 0.0010000000999999998,...
# 989    [0.0010000001, 0.0009999997, 0.0009999998, 0.0...
# Name: Amps, Length: 990, dtype: object

# %%
xvals = np.array(df['Voltage'].values[0])
#yvals = np.array(df['Amps'].values[0])

#xvals_last = np.array(df['Voltage'].values[0])
#yvals_last = np.array(df['Amps'].values[-1])

# %%
# plt.figure(dpi=150)
# plt.semilogy(xvals, abs(yvals), color = 'red', label = '300K')
# plt.semilogy(xvals_last, abs(yvals_last), color = 'darkblue', label = '4K')


# plt.xlim(-5, 1)
# plt.xlabel('Voltage [V]')
# plt.ylabel('Current [Log(A)]')
# plt.legend()
df['Amps']
# Out:
# 0      [0.0009999991, 0.0009999991, 0.001, 0.00099999...
# 1      [0.0009999992000000002, 0.0009999999, 0.001000...
# 2      [0.0009999995999999999, 0.0009999994999999999,...
# 3      [0.0009999989, 0.0009999997999999997, 0.000999...
# 4      [0.0009999985, 0.0010000005, 0.000999999299999...
#                              ...
# 985    [0.0010000013000000002, 0.0009999998000000002,...
# 986    [0.0009999994999999999, 0.0009999998, 0.001, 0...
# 987    [0.0010000001999999999, 0.0009999995, 0.001, 0...
# 988    [0.0009999999000000002, 0.0010000000999999998,...
# 989    [0.0010000001, 0.0009999997, 0.0009999998, 0.0...
# Name: Amps, Length: 990, dtype: object

# %%
from matplotlib.colors import LinearSegmentedColormap
plt.figure(dpi=150)
#cmap = plt.get_cmap('viridis')

colors = [(1, 1, 0), (0, 0, 0.5)]  # Yellow to Dark Blue
cmap_name = 'yellow_to_dark_blue'
cm = LinearSegmentedColormap.from_list(cmap_name, colors)
num_curves = len(df['Amps'])
for i, current_data in enumerate(df['Amps']):
    color = cm(i / (num_curves - 1)) # Determine color based on the position of the curve
    for value in current_data:
        if abs(value) < 1e-17:
            print(f"Curve {i} has a value less than 1e-17: {value}")
            print(df['Time'][i])
    plt.semilogy(xvals, np.abs(current_data), color=color, label=f'Curve {i + 1}')
plt.xlim(0, 1.5)
plt.ylim(1e-14, 10e-3)
plt.xlabel('Voltage [V]')
plt.ylabel('Current [Log(A)]')
#plt.legend()
plt.show()
# Out:
# Curve 171 has a value less than 1e-17: -1.2924697071141058e-27
# Thu Aug 10 17:46:57 2023
# Curve 174 has a value less than 1e-17: 1.9387045606711585e-27
# Thu Aug 10 17:50:32 2023
# Curve 589 has a value less than 1e-17: -6.462348535570529e-28
# Fri Aug 11 02:10:24 2023
